# %% [markdown]
# # Previsão de Votação de Deputados
#
# ### Aluno: Gustavo Silva Medeiros

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats.stats import pearsonr
from sklearn import preprocessing

# %config InlineBackend.figure_format = 'png'
# %matplotlib inline

# %% [markdown]
# ### 2.1) Analisar as distribuições das variáveis para ver se estão enviesadas e precisam de correção; tratamento de valores ausentes, variáveis categóricas e normalização, quando for o caso.

# %%
# colunas utilizadas
cols = [
    "ano",
    "nome",
    "sexo",
    "estado_civil",
    "grau",
    "ocupacao",
    "uf",
    "partido",
    "quantidade_doacoes",
    "quantidade_doadores",
    "total_receita",
    "media_receita",
    "recursos_de_outros_candidatos/comites",
    "recursos_de_pessoas_fisicas",
    "recursos_de_pessoas_juridicas",
    "recursos_proprios",
    "quantidade_despesas",
    "quantidade_fornecedores",
    "total_despesa",
    "media_despesa",
    "votos",
]

df = pd.read_csv("eleicoes_2006_a_2010.csv", usecols=cols, index_col="nome")

# separa os dados de 2006 como treino e os dados de 2010 como teste e remove a coluna "ano"
train = df[(df['ano'] == 2006)].loc[:,'uf':]
test = df[(df['ano'] == 2010)].loc[:,'uf':]

# junta os dados de 2006 e 2010 sem as colunas "ano" e "votos"
all_data = pd.concat((
    train.loc[:,:'ocupacao'],
    test.loc[:,:'ocupacao']
))

# %%
all_data.head()
# Out:
#                                  uf partido  quantidade_doacoes  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA      AP      PT                   6
# LOIVA DE OLIVEIRA                RO      PT                  13
# MARIA DALVA DE SOUZA FIGUEIREDO  AP      PT                  17
# ROMALDO MILANI                   MS   PRONA                   6
# ANSELMO DE JESUS ABREU           RO      PT                  48
#
#                                  quantidade_doadores  total_receita  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                        6       16600.00
# LOIVA DE OLIVEIRA                                 13       22826.00
# MARIA DALVA DE SOUZA FIGUEIREDO                   16      148120.80
# ROMALDO MILANI                                     6        3001.12
# ANSELMO DE JESUS ABREU                            48            NaN
#
#                                  media_receita  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA        2766.666667
# LOIVA DE OLIVEIRA                  1755.846154
# MARIA DALVA DE SOUZA FIGUEIREDO    9257.550000
# ROMALDO MILANI                      500.186667
# ANSELMO DE JESUS ABREU                     NaN
#
#                                  recursos_de_outros_candidatos/comites  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                                        NaN
# LOIVA DE OLIVEIRA                                               6625.0
# MARIA DALVA DE SOUZA FIGUEIREDO                                 2250.0
# ROMALDO MILANI                                                     NaN
# ANSELMO DE JESUS ABREU                                             NaN
#
#                                  recursos_de_pessoas_fisicas  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                           9000.0
# LOIVA DE OLIVEIRA                                    15000.0
# MARIA DALVA DE SOUZA FIGUEIREDO                      34150.0
# ROMALDO MILANI                                        1150.0
# ANSELMO DE JESUS ABREU                               50878.0
#
#                                  recursos_de_pessoas_juridicas  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                            6300.00
# LOIVA DE OLIVEIRA                                      1000.00
# MARIA DALVA DE SOUZA FIGUEIREDO                       62220.80
# ROMALDO MILANI                                         1101.12
# ANSELMO DE JESUS ABREU                                     NaN
#
#                                  recursos_proprios  quantidade_despesas  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                 1300.0                   14
# LOIVA DE OLIVEIRA                            201.0                   24
# MARIA DALVA DE SOUZA FIGUEIREDO            59500.0                  123
# ROMALDO MILANI                               750.0                    8
# ANSELMO DE JESUS ABREU                     68942.0                  133
#
#                                  quantidade_fornecedores  total_despesa  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA
\
# nome
# ANTONIA LUCILEIA CRUZ RAMOS CAMARA             95135.51                   54
# DEODATO NUNES DE FRANÇA                         1500.00                    3
# EDSON FIRMINO DE PAULA                            50.00                    3
# ELISABETH APARECIDA GARCIA RODRIGUES                NaN                    1
# FLAVIANO FLAVIO BAPTISTA DE MELO               10900.00                   83
#
#                                       quantidade_fornecedores  total_despesa  \
# nome
# ANTONIA LUCILEIA CRUZ RAMOS CAMARA                         48      381881.55
# DEODATO NUNES DE FRANÇA                                     3        6990.00
# EDSON FIRMINO DE PAULA                                      3        1840.00
# ELISABETH APARECIDA GARCIA RODRIGUES                        1         440.00
# FLAVIANO FLAVIO BAPTISTA DE MELO                           59      232677.64
#
#                                       media_despesa       sexo  \
# nome
# ANTONIA LUCILEIA CRUZ RAMOS CAMARA      7955.865625   FEMININO
# DEODATO NUNES DE FRANÇA                 2330.000000  MASCULINO
# EDSON FIRMINO DE PAULA                   613.333333  MASCULINO
# ELISABETH APARECIDA GARCIA RODRIGUES     440.000000   FEMININO
# FLAVIANO FLAVIO BAPTISTA DE MELO        3943.688814  MASCULINO
#
#                                                      grau   estado_civil  \
# nome
# ANTONIA LUCILEIA CRUZ RAMOS CAMARA      SUPERIOR COMPLETO      CASADO(A)
# DEODATO NUNES DE FRANÇA                 SUPERIOR COMPLETO      CASADO(A)
# EDSON FIRMINO DE PAULA                SUPERIOR INCOMPLETO      CASADO(A)
# ELISABETH APARECIDA GARCIA RODRIGUES    SUPERIOR COMPLETO      CASADO(A)
# FLAVIANO FLAVIO BAPTISTA DE MELO        SUPERIOR COMPLETO  DIVORCIADO(A)
#
#                                                                                ocupacao  \
# nome
# ANTONIA LUCILEIA CRUZ RAMOS CAMARA                                           EMPRESÁRIO
# DEODATO NUNES DE FRANÇA                                                          OUTROS
# EDSON FIRMINO DE PAULA                OPERADOR DE EQUIPAMENTO DE RÁDIO, TELEVISÃO, S...
# ELISABETH APARECIDA GARCIA RODRIGUES                          PROFESSOR DE ENSINO MÉDIO
# FLAVIANO FLAVIO BAPTISTA DE MELO                                               DEPUTADO
#
#                                       votos
# nome
# ANTONIA LUCILEIA CRUZ RAMOS CAMARA    15849
# DEODATO NUNES DE FRANÇA                4620
# EDSON FIRMINO DE PAULA                  312
# ELISABETH APARECIDA GARCIA RODRIGUES   1357
# FLAVIANO FLAVIO BAPTISTA DE MELO      36301

# %% [markdown]
# #### Data preprocessing

# %%
matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)
prices = pd.DataFrame({"votos":train["votos"], "log(votos + 1)":np.log1p(train["votos"])})
prices.hist()
# Out:
# array([[<AxesSubplot:title={'center':'votos'}>,
#         <AxesSubplot:title={'center':'log(votos + 1)'}>]], dtype=object)

# %%
#log transform the target:
train["votos"] = np.log1p(train["votos"])

#log transform skewed numeric features:
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

skewed_feats = train[numeric_feats].apply(lambda x: skew(x.dropna())) #compute skewness
skewed_feats = skewed_feats[skewed_feats > 0.75]
skewed_feats = skewed_feats.index

all_data[skewed_feats] = np.log1p(all_data[skewed_feats])

# %%
all_data = pd.get_dummies(all_data)
all_data.head()
# Out:
#                                  quantidade_doacoes  quantidade_doadores  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                1.945910             1.945910
# LOIVA DE OLIVEIRA                          2.639057             2.639057
# MARIA DALVA DE SOUZA FIGUEIREDO            2.890372             2.833213
# ROMALDO MILANI                             1.945910             1.945910
# ANSELMO DE JESUS ABREU                     3.891820             3.891820
#
#                                  total_receita  media_receita  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUS
\
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                                                0
# LOIVA DE OLIVEIRA                                                          0
# MARIA DALVA DE SOUZA FIGUEIREDO                                            0
# ROMALDO MILANI                                                             0
# ANSELMO DE JESUS ABREU                                                     0
#
#                                  ocupacao_TÉCNICO EM EDIFICAÇÕES  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                                    0
# LOIVA DE OLIVEIRA                                              0
# MARIA DALVA DE SOUZA FIGUEIREDO                                0
# ROMALDO MILANI                                                 0
# ANSELMO DE JESUS ABREU                                         0
#
#                                  ocupacao_TÉCNICO EM INFORMÁTICA  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                                    0
# LOIVA DE OLIVEIRA                                              0
# MARIA DALVA DE SOUZA FIGUEIREDO                                0
# ROMALDO MILANI                                                 0
# ANSELMO DE JESUS ABREU                                         0
#
#                                  ocupacao_VENDEDOR DE COMÉRCIO VAREJISTA E ATACADISTA  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                                                      0
# LOIVA DE OLIVEIRA                                                                0
# MARIA DALVA DE SOUZA FIGUEIREDO                                                  0
# ROMALDO MILANI                                                                   0
# ANSELMO DE JESUS ABREU                                                           0
#
#                                  ocupacao_VENDEDOR PRACISTA, REPRESENTANTE, CAIXEIRO-VIAJANTE E ASSEMELHADOS  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                                                      0
# LOIVA DE OLIVEIRA                                                                0
# MARIA DALVA DE SOUZA FIGUEIREDO                                                  0
# ROMALDO MILANI                                                                   0
# ANSELMO DE JESUS ABREU                                                           0
#
#                                  ocupacao_VEREADOR  ocupacao_VETERINÁRIO  \
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                      1                     0
# LOIVA DE OLIVEIRA                                0                     0
# MARIA DALVA DE SOUZA FIGUEIREDO                  0                     0
# ROMALDO MILANI                                   0                     0
# ANSELMO DE JESUS ABREU                           0                     0
#
#                                  ocupacao_VIGILANTE  ocupacao_ZOOTECNISTA
# nome
# JOSÉ LUIZ NOGUEIRA DE SOUSA                       0                     0
# LOIVA DE OLIVEIRA                                 0                     0
# MARIA DALVA DE SOUZA FIGUEIREDO                   0                     0
# ROMALDO MILANI                                    0                     0
# ANSELMO DE JESUS ABREU                            0                     0
#
# [5 rows x 259 columns]

# %% [markdown]
# ### 2.2) Construir modelos de regressão com (ridge e lasso) e sem regularização.

# %%
#creating matrices for sklearn:
X_train = all_data[:train.shape[0]]
X_test = all_data[train.shape[0]:]
y = train.votos

# %%
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score

def rmse_cv(model):
    rmse= np.sqrt(-cross_val_score(model, X_train, y, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

# %%
model_ridge = Ridge()

# %%
alphas = [0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 50, 75]
cv_ridge = [rmse_cv(Ridge(alpha = alpha)).mean() 
            for alpha in alphas]

# %%
cv_ridge = pd.Series(cv_ridge, index = alphas)
cv_ridge.plot(title = "Validation - Just Do It")
plt.xlabel("alpha")
plt.ylabel("rmse")
# Out:
# Text(0, 0.5, 'rmse')

# %%
cv_ridge.min()
# Out:
# 0.9479115249847091

# %%
model_lasso = LassoCV(alphas = [1, 0.1, 0.001, 0.0005], max_iter=5000).fit(X_train, y)

# %%
rmse_cv(model_lasso).mean()
# Out:
# 0.9501097590701926

# %%
coef = pd.Series(model_lasso.coef_, index = X_train.columns)

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 103 variables and eliminated the other 156 variables

# %%
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
# Out:
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %%
#let's look at the residuals as well:
matplotlib.rcParams['figure.figsize'] = (6.0, 6.0)

preds = pd.DataFrame({"preds":model_lasso.predict(X_train), "true":y})
preds["residuals"] = preds["true"] - preds["preds"]
preds.plot(x = "preds", y = "residuals",kind = "scatter")
# Out:
# <AxesSubplot:xlabel='preds', ylabel='residuals'>

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(X_train, label = y)
dtest = xgb.DMatrix(X_test)

params = {"max_depth":2, "eta":0.1}
model = xgb.cv(params, dtrain,  num_boost_round=500, early_stopping_rounds=100)
# Out:
# C:\Users\ghust\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# C:\Users\ghust\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
model.loc[30:,["test-rmse-mean", "train-rmse-mean"]].plot()
# Out:
# <AxesSubplot:>

# %%
model_xgb = xgb.XGBRegressor(n_estimators=360, max_depth=2, learning_rate=0.1) #the params were tuned using xgb.cv
model_xgb.fit(X_train, y)
# Out:
# C:\Users\ghust\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=2, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=360, n_jobs=16,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_preds = np.expm1(model_xgb.predict(X_test))
lasso_preds = np.expm1(model_lasso.predict(X_test))

# %%
from scipy import stats

predictions = pd.DataFrame({"xgb":xgb_preds, "lasso":lasso_preds})
predictions = predictions[(np.abs(stats.zscore(predictions)) < 10).all(axis=1)] # remove outliers

predictions.plot(x = "xgb", y = "lasso", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='xgb', ylabel='lasso'>

# %%
preds = 0.7 * lasso_preds + 0.3 * xgb_preds
preds = preds.astype('int') # converte os votos para int

# %%
solution = pd.DataFrame({"nome":test.index, "votos":preds})
solution.to_csv("ridge_sol.csv", index = False)

# %%
solution.head(20)
# Out:
#                                     nome  votos
# 0     ANTONIA LUCILEIA CRUZ RAMOS CAMARA  26641
# 1                DEODATO NUNES DE FRANÇA   1651
# 2                 EDSON FIRMINO DE PAULA    745
# 3   ELISABETH APARECIDA GARCIA RODRIGUES    358
# 4       FLAVIANO FLAVIO BAPTISTA DE MELO  27158
# 5                 FRANCISCO ALVES VIEIRA   1075
# 6   FRANCISCO CARLOS DE OLIVEIRA DE LIMA    801
# 7            FRANCISCO JOSE BENICIO DIAS    938
# 8                   JOSE ALVES DE MORAES    530
# 9                   MARCIO MIGUEL BITTAR  22697
# 10                 MARIA DA ROCHA SEVERO    324
# 11                   MAURICIO DINIZ LIMA    510
# 12      MIGUEL ARCANJO DE SOUZA CARNEIRO    892
# 13             RAIMUNDO NONATO DE CASTRO   2208
# 14           SOLANGE MARIA PINHO PASCOAL   5368
# 15                   UAGLA BELMONT ALVES   1593
# 16     EDILBERTO AFONSO DE MORAES JUNIOR  18948
# 17                FERNANDO MELO DA COSTA  27846
# 18                  GEHLEN DINIZ ANDRADE   3992
# 19              GILSON GOMES DE OLIVEIRA   4584

# %% [markdown]
# ### 2.3) Considerar outros modelos ainda não vistos em sala de sua escolha (e.g. SVR, Regression Trees, KNN e Random Florests).

# %% [markdown]
# #### RandomForestRegressor

# %%
train_features = X_train
train_labels = y
test_features = X_test
test_labels = test.votos

# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 50, random_state = 42, max_depth=8)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 22454.66 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 0.94 %.
